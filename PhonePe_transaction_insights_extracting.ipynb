# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
#pulse/data/aggregated/insurance
import os
path="/content/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Insur=pd.DataFrame(clm)

# %%
Agg_Insur
# Out:
#        State  Year  Quater Transacion_type  Transacion_count  \
# 0    gujarat  2021       3       Insurance             15348
# 1    gujarat  2021       4       Insurance             19142
# 2    gujarat  2021       1       Insurance             12673
# 3    gujarat  2021       2       Insurance             14676
# 4    gujarat  2020       3       Insurance             12525
# ..       ...   ...     ...             ...               ...
# 677   sikkim  2022       2       Insurance               160
# 678   sikkim  2023       3       Insurance               251
# 679   sikkim  2023       4       Insurance               324
# 680   sikkim  2023       1       Insurance               260
# 681   sikkim  2023       2       Insurance               270
#
#      Transacion_amount
# 0           12341903.0
# 1           23282921.0
# 2            7288104.0
# 3           10263998.0
# 4            3335812.0
# ..                 ...
# 677           383709.0
# 678           698251.0
# 679           793745.0
# 680           688605.0
# 681           628191.0
#
# [682 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Agg_Insur.to_csv("Agg_Insur.csv", index=False)

print("CSV file 'Agg_Insur.csv' saved successfully!")
# Out:
# CSV file 'Agg_Insur.csv' saved successfully!

# %%
#pulse/data/aggregated/transaction
import os
path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#         State  Year  Quarter          Transaction_type  Transaction_count  \
# 0     tripura  2020        3  Recharge & bill payments             627363
# 1     tripura  2020        3     Peer-to-peer payments             477769
# 2     tripura  2020        3         Merchant payments             202106
# 3     tripura  2020        3        Financial Services               3828
# 4     tripura  2020        3                    Others               6819
# ...       ...   ...      ...                       ...                ...
# 5029  manipur  2021        2     Peer-to-peer payments            1372821
# 5030  manipur  2021        2  Recharge & bill payments            1187952
# 5031  manipur  2021        2         Merchant payments             510734
# 5032  manipur  2021        2        Financial Services               4165
# 5033  manipur  2021        2                    Others              10603
#
#       Transaction_amount
# 0           1.852020e+08
# 1           1.959371e+09
# 2           1.902181e+08
# 3           3.141392e+06
# 4           3.886908e+06
# ...                  ...
# 5029        7.041838e+09
# 5030        3.051038e+08
# 5031        5.314848e+08
# 5032        4.256098e+06
# 5033        7.145346e+06
#
# [5034 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Agg_Trans.to_csv("Agg_Trans.csv", index=False)

print("CSV file 'Agg_Trans.csv' saved successfully!")
# Out:
# CSV file 'Agg_Trans.csv' saved successfully!

# %%
#pulse/data/aggregated/user
import os
path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
import pandas as pd
import json
import os

# Define the path to the data directory
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {'State': [], 'Year': [], 'Quarter': [], 'Brand': [], 'Registered_Users': [], 'App_Opens': [], 'Total_Registered_Users': [], 'Total_App_Opens': []}

# Extracting data to create a dataframe
for i in Agg_state_list:
    p_i = path + i + "/"
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                total_registered_users = D['data']['aggregated']['registeredUsers']
                total_app_opens = D['data']['aggregated']['appOpens']

                if 'usersByDevice' in D['data'] and D['data']['usersByDevice'] is not None:
                    for z in D['data']['usersByDevice']:
                        clm['Brand'].append(z['brand'])
                        clm['Registered_Users'].append(z['count'])
                        clm['App_Opens'].append(total_app_opens)
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quarter'].append(int(k.strip('.json')))
                        clm['Total_Registered_Users'].append(total_registered_users)
                        clm['Total_App_Opens'].append(total_app_opens)

# Successfully created a dataframe
Agg_Users = pd.DataFrame(clm)

# %%
Agg_Users
# Out:
#         State  Year  Quarter       Brand  Registered_Users  App_Opens  \
# 0     tripura  2020        3      Xiaomi             93468    5777908
# 1     tripura  2020        3     Samsung             86403    5777908
# 2     tripura  2020        3        Oppo             52607    5777908
# 3     tripura  2020        3        Vivo             44208    5777908
# 4     tripura  2020        3      Realme             33649    5777908
# ...       ...   ...      ...         ...               ...        ...
# 6727  manipur  2021        2      Huawei              3685    7269002
# 6728  manipur  2021        2     OnePlus              3183    7269002
# 6729  manipur  2021        2    Motorola              2290    7269002
# 6730  manipur  2021        2  HMD Global              2192    7269002
# 6731  manipur  2021        2      Others             16949    7269002
#
#       Total_Registered_Users  Total_App_Opens
# 0                     376731          5777908
# 1                     376731          5777908
# 2                     376731          5777908
# 3                     376731          5777908
# 4                     376731          5777908
# ...                      ...              ...
# 6727                  335409          7269002
# 6728                  335409          7269002
# 6729                  335409          7269002
# 6730                  335409          7269002
# 6731                  335409          7269002
#
# [6732 rows x 8 columns]

# %%
import json
import os
import pandas as pd

# This is to extract the data and create a DataFrame
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)  # List of states in India

clm = {'State': [], 'Year': [], 'Quarter': [], 'User_Brand': [], 'User_Count': [], 'User_Percentage': []}

for i in Agg_state_list:
    state_path = os.path.join(path, i)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    users_by_device = D.get('data', {}).get('usersByDevice', [])

                    if users_by_device:
                        for device in users_by_device:
                            clm['State'].append(i)
                            clm['Year'].append(year)
                            clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                            clm['User_Brand'].append(device.get('brand', 'Unknown'))
                            clm['User_Count'].append(device.get('count', 0))
                            clm['User_Percentage'].append(device.get('percentage', 0.0))

            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(i)
                clm['Year'].append(year)
                clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                clm['User_Brand'].append(None)
                clm['User_Count'].append(0)
                clm['User_Percentage'].append(0.0)

# Successfully created a DataFrame
Agg_Users = pd.DataFrame(clm)

# %%
Agg_Users
# Out:
#         State  Year  Quarter  User_Brand  User_Count  User_Percentage
# 0     tripura  2020        3      Xiaomi       93468         0.248103
# 1     tripura  2020        3     Samsung       86403         0.229349
# 2     tripura  2020        3        Oppo       52607         0.139641
# 3     tripura  2020        3        Vivo       44208         0.117346
# 4     tripura  2020        3      Realme       33649         0.089318
# ...       ...   ...      ...         ...         ...              ...
# 6727  manipur  2021        2      Huawei        3685         0.010987
# 6728  manipur  2021        2     OnePlus        3183         0.009490
# 6729  manipur  2021        2    Motorola        2290         0.006827
# 6730  manipur  2021        2  HMD Global        2192         0.006535
# 6731  manipur  2021        2      Others       16949         0.050532
#
# [6732 rows x 6 columns]

# %%
import os
import json
import pandas as pd

# Define the path to the data directory
path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {
    'State': [], 'Year': [], 'Quarter': [], 'Brand': [], 'Registered_Users': [], 'App_Opens': [],
    'Total_Registered_Users': [], 'Total_App_Opens': [], 'User_Percentage': []
}

# Extracting data to create a dataframe
for state in Agg_state_list:
    state_path = os.path.join(path, state)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    total_registered_users = D.get('data', {}).get('aggregated', {}).get('registeredUsers', 0)
                    total_app_opens = D.get('data', {}).get('aggregated', {}).get('appOpens', 0)
                    users_by_device = D.get('data', {}).get('usersByDevice', [])

                    if users_by_device:
                        for device in users_by_device:
                            clm['State'].append(state)
                            clm['Year'].append(year)
                            clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                            clm['Brand'].append(device.get('brand', 'Unknown'))
                            clm['Registered_Users'].append(device.get('count', 0))
                            clm['App_Opens'].append(total_app_opens)
                            clm['Total_Registered_Users'].append(total_registered_users)
                            clm['Total_App_Opens'].append(total_app_opens)
                            clm['User_Percentage'].append(device.get('percentage', 0.0))
                    else:
                        clm['State'].append(state)
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                        clm['Brand'].append(None)
                        clm['Registered_Users'].append(0)
                        clm['App_Opens'].append(0)
                        clm['Total_Registered_Users'].append(0)
                        clm['Total_App_Opens'].append(0)
                        clm['User_Percentage'].append(0.0)
            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(state)
                clm['Year'].append(year)
                clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                clm['Brand'].append(None)
                clm['Registered_Users'].append(0)
                clm['App_Opens'].append(0)
                clm['Total_Registered_Users'].append(0)
                clm['Total_App_Opens'].append(0)
                clm['User_Percentage'].append(0.0)

# Successfully created a DataFrame
Agg_Users = pd.DataFrame(clm)
print(Agg_Users.head())
# Out:
#      State  Year  Quarter    Brand  Registered_Users  App_Opens  \
# 0  tripura  2020        3   Xiaomi             93468    5777908
# 1  tripura  2020        3  Samsung             86403    5777908
# 2  tripura  2020        3     Oppo             52607    5777908
# 3  tripura  2020        3     Vivo             44208    5777908
# 4  tripura  2020        3   Realme             33649    5777908
#
#    Total_Registered_Users  Total_App_Opens  User_Percentage
# 0                  376731          5777908         0.248103
# 1                  376731          5777908         0.229349
# 2                  376731          5777908         0.139641
# 3                  376731          5777908         0.117346
# 4                  376731          5777908         0.089318

# %%
# Save the DataFrame as a CSV file
Agg_Users.to_csv("Agg_Users.csv", index=False)

print("CSV file 'Agg_Users.csv' saved successfully!")
# Out:
# CSV file 'Agg_Users.csv' saved successfully!

# %%
#pulse/data/map/insurance
import os
path="/content/pulse/data/map/insurance/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/insurance/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
#map_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quarter':[],'Insurance_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in map_state_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Insurance_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insur=pd.DataFrame(clm)

# %%
Map_Insur
# Out:
#          State  Year  Quarter          Insurance_type  Insurance_count  \
# 0      tripura  2020        3        unakoti district               13
# 1      tripura  2020        3         khowai district                8
# 2      tripura  2020        3     sepahijala district               24
# 3      tripura  2020        3  north tripura district               28
# 4      tripura  2020        3         dhalai district               17
# ...        ...   ...      ...                     ...              ...
# 13871  manipur  2021        2       kakching district                6
# 13872  manipur  2021        2     tengnoupal district                4
# 13873  manipur  2021        2        jiribam district                3
# 13874  manipur  2021        2         ukhrul district                8
# 13875  manipur  2021        2    imphal west district               37
#
#        Insurance_amount
# 0                3504.0
# 1                1711.0
# 2                5870.0
# 3                6036.0
# 4                3839.0
# ...                 ...
# 13871            1638.0
# 13872            1439.0
# 13873             513.0
# 13874            4637.0
# 13875           32816.0
#
# [13876 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Map_Insur.to_csv("Map_Insur.csv", index=False)

print("CSV file 'Map_Insur.csv' saved successfully!")
# Out:
# CSV file 'Map_Insur.csv' saved successfully!

# %%
#pulse/data/map/transaction
import os
path="/content/pulse/data/map/transaction/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/transaction/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
#map_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in map_state_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Trans=pd.DataFrame(clm)

# %%
Map_Trans
# Out:
#          State  Year  Quarter        Transaction_type  Transaction_count  \
# 0      tripura  2020        3        unakoti district              63441
# 1      tripura  2020        3         khowai district              72823
# 2      tripura  2020        3     sepahijala district             144693
# 3      tripura  2020        3  north tripura district             126884
# 4      tripura  2020        3         dhalai district             114616
# ...        ...   ...      ...                     ...                ...
# 20599  manipur  2021        2       senapati district              25681
# 20600  manipur  2021        2       pherzawl district               1842
# 20601  manipur  2021        2  churachandpur district              80524
# 20602  manipur  2021        2     tengnoupal district              23771
# 20603  manipur  2021        2    imphal west district            2353896
#
#        Transaction_amount
# 0            1.189579e+08
# 1            1.297611e+08
# 2            2.693501e+08
# 3            2.079651e+08
# 4            1.924036e+08
# ...                   ...
# 20599        7.021966e+07
# 20600        5.443831e+06
# 20601        2.739623e+08
# 20602        9.480697e+07
# 20603        5.697696e+09
#
# [20604 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Map_Trans.to_csv("Map_Trans.csv", index=False)

print("CSV file 'Map_Trans.csv' saved successfully!")
# Out:
# CSV file 'Map_Trans.csv' saved successfully!

# %%
#pulse/data/map/user
import os
path="/content/pulse/data/map/user/hover/country/india/state/"
map_state_list=os.listdir(path)
map_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
import pandas as pd
import json
import os

# This is to direct the path to get the data as states
path = "/content/pulse/data/map/user/hover/country/india/state/"
map_state_list = os.listdir(path)  # List of states in India

# Extracting data to create a DataFrame
clm = {'State': [], 'Year': [], 'Quarter': [], 'Registered_Users': [], 'App_Opens': []}

for i in map_state_list:
    state_path = os.path.join(path, i)
    for year in os.listdir(state_path):
        year_path = os.path.join(state_path, year)
        for quarter_file in os.listdir(year_path):
            file_path = os.path.join(year_path, quarter_file)
            try:
                with open(file_path, 'r') as Data:
                    D = json.load(Data)
                    hover_data = D.get('data', {}).get('hoverData', {})

                    for location, details in hover_data.items():
                        clm['State'].append(i)
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                        clm['Registered_Users'].append(details.get('registeredUsers', 0))
                        clm['App_Opens'].append(details.get('appOpens', 0))

            except (KeyError, json.JSONDecodeError, TypeError) as e:
                print(f"Error processing file {file_path}: {e}")
                clm['State'].append(i)
                clm['Year'].append(year)
                clm['Quarter'].append(int(quarter_file.replace('.json', '')))
                clm['Registered_Users'].append(0)
                clm['App_Opens'].append(0)

# Successfully created a DataFrame
Map_Users = pd.DataFrame(clm)

# %%
Map_Users
# Out:
#          State  Year  Quarter  Registered_Users  App_Opens
# 0      tripura  2020        3             20095     283289
# 1      tripura  2020        3             23565     338549
# 2      tripura  2020        3             39970     669235
# 3      tripura  2020        3             37284     558658
# 4      tripura  2020        3             29515     496111
# ...        ...   ...      ...               ...        ...
# 20603  manipur  2021        2              1769    1295855
# 20604  manipur  2021        2               663      77344
# 20605  manipur  2021        2             25573     552013
# 20606  manipur  2021        2              6499     242939
# 20607  manipur  2021        2            102833     945286
#
# [20608 rows x 5 columns]

# %%
# Save the DataFrame as a CSV file
Map_Users.to_csv("Map_Users.csv", index=False)

print("CSV file 'Map_Users.csv' saved successfully!")
# Out:
# CSV file 'Map_Users.csv' saved successfully!

# %%
#pulse/data/top/insurance
import os
path="/content/pulse/data/top/insurance/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
import pandas as pd
import json
import os

# Path to the data
path = "/content/pulse/data/top/insurance/country/india/"

# Initialize DataFrame structure
clm = {'State/District/Pincode': [], 'Year': [], 'Quarter': [], 'Category': [], 'Insurance_count': [], 'Insurance_amount': []}

# Loop through the available years
for year in os.listdir(path):
    year_path = os.path.join(path, year)

    # Check if it's a valid directory
    if not os.path.isdir(year_path):
        continue

    # Loop through all JSON files directly inside the Year folder
    for file in os.listdir(year_path):
        if file.endswith(".json"):
            file_path = os.path.join(year_path, file)

            with open(file_path, 'r') as Data:
                D = json.load(Data)

            # Extract state/district/pincode level data
            for category in ["states", "districts", "pincodes"]:
                if category in D["data"]:
                    for entry in D["data"][category]:
                        clm['State/District/Pincode'].append(entry["entityName"])
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(file.strip('.json')))  # Extract quarter from filename
                        clm['Category'].append(category)
                        clm['Insurance_count'].append(entry["metric"]["count"])
                        clm['Insurance_amount'].append(entry["metric"]["amount"])

# Convert to DataFrame
Top_Insur = pd.DataFrame(clm)

# %%
Top_Insur
# Out:
#     State/District/Pincode  Year  Quarter  Category  Insurance_count  \
# 0              maharashtra  2020        3    states            71662
# 1                karnataka  2020        3    states            53701
# 2           andhra pradesh  2020        3    states            49812
# 3                telangana  2020        3    states            34395
# 4            uttar pradesh  2020        3    states            18131
# ..                     ...   ...      ...       ...              ...
# 565                 421302  2021        2  pincodes              783
# 566                 712138  2021        2  pincodes              724
# 567                 411033  2021        2  pincodes              722
# 568                 560076  2021        2  pincodes              719
# 569                 412105  2021        2  pincodes              713
#
#      Insurance_amount
# 0          19230156.0
# 1          12407394.0
# 2          12426481.0
# 3           8406543.0
# 4           4436969.0
# ..                ...
# 565          586297.0
# 566          263805.0
# 567          405598.0
# 568          556220.0
# 569          452166.0
#
# [570 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Top_Insur.to_csv("Top_Insur.csv", index=False)

print("CSV file 'Top_Insur.csv' saved successfully!")
# Out:
# CSV file 'Top_Insur.csv' saved successfully!

# %%
#pulse/data/top/transaction
import os
path="/content/pulse/data/top/transaction/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
import pandas as pd
import json
import os

# Path to the data
path = "/content/pulse/data/top/transaction/country/india/"

# Initialize DataFrame structure
clm = {'State/District/Pincode': [], 'Year': [], 'Quarter': [], 'Category': [], 'Transaction_count': [], 'Transaction_amount': []}

# Loop through the available years
for year in os.listdir(path):
    year_path = os.path.join(path, year)

    # Check if it's a valid directory
    if not os.path.isdir(year_path):
        continue

    # Loop through all JSON files directly inside the Year folder
    for file in os.listdir(year_path):
        if file.endswith(".json"):
            file_path = os.path.join(year_path, file)

            with open(file_path, 'r') as Data:
                D = json.load(Data)

            # Extract state/district/pincode level data
            for category in ["states", "districts", "pincodes"]:
                if category in D["data"]:
                    for entry in D["data"][category]:
                        clm['State/District/Pincode'].append(entry["entityName"])
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(file.strip('.json')))  # Extract quarter from filename
                        clm['Category'].append(category)
                        clm['Transaction_count'].append(entry["metric"]["count"])
                        clm['Transaction_amount'].append(entry["metric"]["amount"])

# Convert to DataFrame
Top_Trans = pd.DataFrame(clm)

# %%
Top_Trans
# Out:
#     State/District/Pincode  Year  Quarter  Category  Transaction_count  \
# 0                karnataka  2020        3    states          300360531
# 1              maharashtra  2020        3    states          268310924
# 2                telangana  2020        3    states          236372126
# 3           andhra pradesh  2020        3    states          204902935
# 4                rajasthan  2020        3    states          149088676
# ..                     ...   ...      ...       ...                ...
# 835                 110006  2021        2  pincodes           54888173
# 836                 800001  2021        2  pincodes           42836603
# 837                 600003  2021        2  pincodes           31694305
# 838                 751001  2021        2  pincodes           30961581
# 839                 700009  2021        2  pincodes           30775525
#
#      Transaction_amount
# 0          4.707405e+11
# 1          4.403071e+11
# 2          5.059611e+11
# 3          4.670841e+11
# 4          2.936783e+11
# ..                  ...
# 835        8.884931e+10
# 836        9.178168e+10
# 837        5.428202e+10
# 838        5.356578e+10
# 839        5.958722e+10
#
# [840 rows x 6 columns]

# %%
# Save the DataFrame as a CSV file
Top_Trans.to_csv("Top_Trans.csv", index=False)

print("CSV file 'Top_Trans.csv' saved successfully!")
# Out:
# CSV file 'Top_Trans.csv' saved successfully!

# %%
#pulse/data/top/user
import os
path="/content/pulse/data/top/user/country/india/state/"
top_state_list=os.listdir(path)
top_state_list
# Out:
# ['tripura',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'karnataka',
#  'haryana',
#  'tamil-nadu',
#  'goa',
#  'arunachal-pradesh',
#  'meghalaya',
#  'nagaland',
#  'west-bengal',
#  'lakshadweep',
#  'punjab',
#  'himachal-pradesh',
#  'andaman-&-nicobar-islands',
#  'sikkim',
#  'madhya-pradesh',
#  'andhra-pradesh',
#  'gujarat',
#  'uttarakhand',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'jammu-&-kashmir',
#  'delhi',
#  'uttar-pradesh',
#  'jharkhand',
#  'puducherry',
#  'maharashtra',
#  'kerala',
#  'ladakh',
#  'chhattisgarh',
#  'bihar',
#  'chandigarh',
#  'assam',
#  'odisha',
#  'manipur']

# %%
import pandas as pd
import json
import os

# Define the path to user registration data
path = "/content/pulse/data/top/user/country/india/state/"
user_state_list = os.listdir(path)

# Dictionary to store extracted data
clm = {'State/District/Pincode': [], 'Year': [], 'Quarter': [], 'Registered_Users': []}

for state in user_state_list:
    state_path = os.path.join(path, state)
    years = os.listdir(state_path)

    for year in years:
        year_path = os.path.join(state_path, year)
        quarters = os.listdir(year_path)

        for quarter in quarters:
            quarter_path = os.path.join(year_path, quarter)

            # Read JSON file
            with open(quarter_path, 'r') as data_file:
                D = json.load(data_file)

            # Ensure 'data' exists before accessing its keys
            if 'data' in D and D['data']:

                # Process state-level data
                if 'states' in D['data'] and D['data']['states']:
                    for state_data in D['data']['states']:
                        clm['State/District/Pincode'].append(state_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(state_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

                # Process district-level data
                if 'districts' in D['data'] and D['data']['districts']:
                    for district_data in D['data']['districts']:
                        clm['State/District/Pincode'].append(district_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(district_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

                # Process pincode-level data
                if 'pincodes' in D['data'] and D['data']['pincodes']:
                    for pincode_data in D['data']['pincodes']:
                        clm['State/District/Pincode'].append(pincode_data.get('name', 'Unknown'))
                        clm['Registered_Users'].append(pincode_data.get('registeredUsers', 0))
                        clm['Year'].append(year)
                        clm['Quarter'].append(int(quarter.strip('.json')))

# Convert dictionary to DataFrame
Top_Users = pd.DataFrame(clm)

# %%
Top_Users
# Out:
#       State/District/Pincode  Year  Quarter  Registered_Users
# 0               west tripura  2020        3            151432
# 1              south tripura  2020        3             40797
# 2                 sepahijala  2020        3             39970
# 3              north tripura  2020        3             37284
# 4                     gomati  2020        3             34073
# ...                      ...   ...      ...               ...
# 18291                 795008  2021        2             11401
# 18292                 795002  2021        2             11348
# 18293                 795148  2021        2             10740
# 18294                 795010  2021        2             10542
# 18295                 795149  2021        2             10473
#
# [18296 rows x 4 columns]

# %%
# Save the DataFrame as a CSV file
Top_Users.to_csv("Top_Users.csv", index=False)

print("CSV file 'Top_Users.csv' saved successfully!")
# Out:
# CSV file 'Top_Users.csv' saved successfully!
